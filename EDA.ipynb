# %%
import pandas as pd
import os

# %% [markdown]
# # Extracción de datos de Maps

# %%
dfx = pd.DataFrame()
for i in range(1,12):
    df = pd.read_json(f'C:/Users/tinma/OneDrive/Escritorio/Google Maps/metadata-sitios/{i}.json',lines=True)
    pd.concat([dfx,df])
dfx
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
source_path = 'C:/Users/tinma/OneDrive/Escritorio/Google Maps/estados'

lista = os.listdir(f'{source_path}')
dfx = pd.DataFrame()
for i in lista:
    list_ = os.listdir(f'{source_path}/{i}')
    for j in list_:
        df = pd.read_json(f'{source_path}/{i}/{j}',lines=True)
        dfx = pd.concat([dfx,df],axis=0)

dfx
# Out:
#              user_id             name           time  rating  \
# 0       1.089912e+20          Song Ro  1609909927056       5
# 1       1.112903e+20      Rafa Robles  1612849648663       5
# 2       1.126404e+20        David Han  1583643882296       4
# 3       1.174403e+20      Anthony Kim  1551938216355       5
# 4       1.005808e+20    Mario Marzouk  1494910901933       5
# ...              ...              ...            ...     ...
# 149995  1.021681e+20       t williams  1562883151018       5
# 149996  1.054173e+20       Erika Lira  1532009672494       5
# 149997  1.107857e+20        Jon Brent  1567968578697       5
# 149998  1.091676e+20      lunna cabal  1506476840285       4
# 149999  1.012701e+20  Michelle Torres  1555551049893       5
#
#                                                     text  pics  resp  \
# 0                           Love there korean rice cake.  None  None
# 1                                         Good very good  None  None
# ...

# %%
pd.read_json(f'{source_path}/review-California/1.json',lines=True)

# %%
pd.read_json(f'{source_path}/{i}/{j}',lines=True)
# Out:
#              user_id             name           time  rating  text  pics  \
# 0       1.061903e+20     Raza Hussain  1496027009883       5  None  None
# 1       1.088400e+20     Janet Denney  1575473992383       5  None  None
# 2       1.120277e+20     its.yaboineb  1509840227559       5  None  None
# 3       1.170677e+20    street Adrian  1496209109675       5  None  None
# 4       1.027301e+20           josh r  1531173345808       2  None  None
# ...              ...              ...            ...     ...   ...   ...
# 149995  1.021681e+20       t williams  1562883151018       5  None  None
# 149996  1.054173e+20       Erika Lira  1532009672494       5  None  None
# 149997  1.107857e+20        Jon Brent  1567968578697       5  None  None
# 149998  1.091676e+20      lunna cabal  1506476840285       4  None  None
# 149999  1.012701e+20  Michelle Torres  1555551049893       5  None  None
#
#         resp                                gmap_id
# ...

# %%
source_path = 'C:/Users/tinma/OneDrive/Escritorio/Google Maps/metadata-sitios'

pd.read_json(f'{source_path}/1.json',lines=True)
# Out:
#                                    name  \
# 0                       Porter Pharmacy
# 1                          City Textile
# 2                          San Soo Dang
# 3                          Nova Fabrics
# 4                      Nobel Textile Co
# ...                                 ...
# 274996                     Maven Realty
# 274997               Stone Castle Fence
# 274998  Health Insurance Solutions Team
# 274999          Bernard Building Center
# 275000    HMR Motor Works and Auto Care
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                   ...
# 274996  Maven Realty, 2180 McMillan Ave #71672, North ...
# ...

# %%
source_path = 'C:/Users/tinma/OneDrive/Escritorio/Google Maps/metadata-sitios'

lista = os.listdir(f'{source_path}')
dfx = pd.DataFrame()
for i in lista:
    df = pd.read_json(f'{source_path}/{i}',lines=True)
    dfx = pd.concat([dfx,df],axis=0)

dfx
# Out:
#                                      name  \
# 0                         Porter Pharmacy
# 1                            City Textile
# 2                            San Soo Dang
# 3                            Nova Fabrics
# 4                        Nobel Textile Co
# ...                                   ...
# 274996     The Green Room Of Libertyville
# 274997           Klein Brothers Packaging
# 274998               Profiles Hair Design
# 274999                     Arizona LINE-X
# 275000  US Forest Services Ranger Station
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                   ...
# ...

# %%
dfx = dfx.reset_index(drop=True)
dfx
# Out:
#                                       name  \
# 0                          Porter Pharmacy
# 1                             City Textile
# 2                             San Soo Dang
# 3                             Nova Fabrics
# 4                         Nobel Textile Co
# ...                                    ...
# 3025006     The Green Room Of Libertyville
# 3025007           Klein Brothers Packaging
# 3025008               Profiles Hair Design
# 3025009                     Arizona LINE-X
# 3025010  US Forest Services Ranger Station
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1        City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3        Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                    ...
# ...

# %%
dfx.category[0]
# Out:
# ['Pharmacy']

# %%
list_idx = []

for i in range(len(dfx)):
    for j in dfx.category:
        if type(j) != list or type(j) != str:
            list_idx.append(i)

dfx.loc[list_idx]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Untitled-1.ipynb Celda 10 in 6
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X34sdW50aXRsZWQ%3D?line=3'>4</a>     for j in dfx.category:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X34sdW50aXRsZWQ%3D?line=4'>5</a>         if type(j) != list or type(j) != str:
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X34sdW50aXRsZWQ%3D?line=5'>6</a>             list_idx.append(i)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X34sdW50aXRsZWQ%3D?line=7'>8</a> dfx.loc[list_idx]
#
# MemoryError:

# %%
list_idx = []

for i in range(len(dfx)):
    for j in dfx.category:
        for k in j:
            if 'restaurant' in k or 'Restaurant' in k:
                list_idx.append(i)

dfx.loc[list_idx]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Celda 10 in 5
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X25sdW50aXRsZWQ%3D?line=2'>3</a> for i in range(len(dfx)):
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X25sdW50aXRsZWQ%3D?line=3'>4</a>     for j in dfx.category:
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X25sdW50aXRsZWQ%3D?line=4'>5</a>         for k in j:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X25sdW50aXRsZWQ%3D?line=5'>6</a>             if 'restaurant' in k or 'Restaurant' in k:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X25sdW50aXRsZWQ%3D?line=6'>7</a>                 list_idx.append(i)
#
# TypeError: 'NoneType' object is not iterable

# %%
dfx_cadenas.groupby('name')['gmap_id'].count()
# Out:
# name
# Dunkin Donuts      22
# KFC               415
# Subway           9140
# Taco Bell         685
# Waffle House      115
# Name: gmap_id, dtype: int64

# %% [markdown]
# # Extracción de datos de Yelp

# %%
dfy_rev = pd.read_json(r'C:\Users\tinma\OneDrive\Escritorio\Yelp\review.json',lines=True)
dfy_rev
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# ...

# %%
for x in dfy_rev.columns:
    print(x,dfy_rev[x].dtype)
# Out:
# review_id object
# user_id object
# business_id object
# stars int64
# useful int64
# funny int64
# cool int64
# text object
# date datetime64[ns]

# %%
dfy_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        int64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 480.0+ MB

# %%
dfy_rev.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
dfy_rev.describe()
# Out:
#               stars        useful         funny          cool
# count  6.990280e+06  6.990280e+06  6.990280e+06  6.990280e+06
# mean   3.748584e+00  1.184609e+00  3.265596e-01  4.986175e-01
# std    1.478705e+00  3.253767e+00  1.688729e+00  2.172460e+00
# min    1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    5.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# max    5.000000e+00  1.182000e+03  7.920000e+02  4.040000e+02

# %%
dfy_user = pd.read_parquet(r'C:\Users\tinma\OneDrive\Escritorio\Yelp\ .parquet')
dfy_user
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %%
df_tip = pd.read_json(r'C:\Users\tinma\OneDrive\Escritorio\Yelp\tip.json',lines=True)
df_tip
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date  \
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# ...

# %%
dfy_bsi = pd.read_pickle(r'C:\Users\tinma\OneDrive\Escritorio\Yelp\business.pkl')
dfy_bsi = dfy_bsi.iloc[:,:14]
dfy_chip = dfy_bsi[dfy_bsi.name=='Chipotle']
dfy_chip
# Out:
#                    business_id      name                      address  \
# 115794  1MVoJvPhP5SkrJGCxuriaQ  Chipotle  1851 S Columbus Blvd, Ste 3
#
#                 city state postal_code   latitude  longitude stars  \
# 115794  Philadelphia    TN       19148  39.923491 -75.140583   1.0
#
#        review_count is_open  \
# 115794            8       1
#
#                                                attributes  \
# 115794  {'RestaurantsDelivery': 'True', 'RestaurantsTa...
#
#                              categories  \
# 115794  Fast Food, Restaurants, Mexican
#
#                                                     hours
# 115794  {'Monday': '0:0-0:0', 'Tuesday': '10:45-22:0',...

# %%
dfy_bsi[dfy_bsi.name == 'McDonalds']
# Out:
#                    business_id       name                          address  \
# 28756   2d7rO6a0HdyEg2Nnf3kLKg  McDonalds               11240 82 Street NW
# 91266   A1hHP1HZfebuI9-sdieZBQ  McDonalds              34 Avenue 99 Street
# 102306  ln57otfbTmN8FsLlR4x57Q  McDonalds  30th St Station, 2951 Market St
# 103477  jDGxzwlkyH3I7_LghcxLAA  McDonalds  Philadelphia Airport Terminal E
# 128629  FKwQsrcZXy-NUKszOcV8mQ  McDonalds                     934 Canal St
#
#                 city state postal_code   latitude   longitude stars  \
# 28756       Edmonton    PA     T5B 0C1  53.561686 -113.466926   2.0
# 91266       Edmonton    TN     T5V 1T8  53.468252 -113.486935   2.0
# 102306  Philadelphia    FL       19104  39.961793   -75.19721   2.5
# 103477  Philadelphia    ID       19153  39.877906  -75.236665   2.0
# 128629   New Orleans    NV       70112  29.954638  -90.071902   2.0
#
#        review_count is_open  \
# 28756            10       1
# 91266            14       1
# ...

# %%
'review-New_York'[7:]
# Out:
# 'New_York'
