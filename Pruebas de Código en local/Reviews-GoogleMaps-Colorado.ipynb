# %%
import pandas as pd
import json
import os

# Lista de rutas de archivos JSON
rutas_archivos = [
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/1.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/2.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/3.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/4.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/5.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/6.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/7.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/8.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/9.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/10.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/11.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/12.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/13.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/14.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/15.json",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Google maps/Reviews-estados/review-Colorado/16.json",
]

# Crear una lista para almacenar los datos JSON
datos_json = []

# Recorrer todas las rutas de archivos y cargar los datos JSON
for ruta_archivo in rutas_archivos:
    try:
        with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
            # Leer líneas del archivo
            lineas = archivo.readlines()

        for linea in lineas:
            # Intentar cargar cada línea como un objeto JSON y agregarlo a la lista
            try:
                datos_json.append(json.loads(linea))
            except json.JSONDecodeError as e:
                print(f"Error al decodificar la línea como JSON en {ruta_archivo}: {e}")
    except FileNotFoundError:
        print(f"El archivo JSON no se encontró en la ruta especificada: {ruta_archivo}")
    except Exception as e:
        print(f"Ocurrió un error: {e}")

# Crear un DataFrame a partir de la lista de datos JSON
df_review_Colorado_final = pd.DataFrame(datos_json)

# Mostrar el DataFrame
from IPython.display import display
display(df_review_Colorado_final)

#Guardar el DataFrame en un archivo CSV
df_review_Colorado_final.to_csv("review-Colorado-Final.csv", index=False)
# Out:
#                        user_id                            name           time  \
# 0        108990457316763116222                     mgshouldice  1484353876202
# 1        107403966474786136203               Sabrina Holsinger  1484195642287
# 2        112819818945043576491                       Tad Amore  1459554530689
# 3        102591757433717355980  Victoria Elizabeth De La Torre  1483746469128
# 4        104008941864455933539               Luis Garcia-Lopez  1542782383361
# ...                        ...                             ...            ...
# 2399995  109190888617291633055                   Angela Thomas  1612558777044
# 2399996  110564008290562281593                  Dylan Anderson  1579446667479
# 2399997  114554663647856620889                    Diego Guzman  1557236520261
# 2399998  115789342917984970047                        Alex Sun  1598114277690
# 2399999  101741915752519070535                    Andres Prada  1583183437137
#
# ...
